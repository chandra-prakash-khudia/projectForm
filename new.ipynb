# %% [markdown]
# <a href="https://colab.research.google.com/github/chandra-prakash-khudia/projectForm/blob/main/new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python3 -m pip install paddlepaddle-gpu
# Out:
# Collecting paddlepaddle-gpu
#   Downloading paddlepaddle_gpu-2.6.2-cp310-cp310-manylinux1_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (0.28.1)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (11.0.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (4.4.2)
# Collecting astor (from paddlepaddle-gpu)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting opt-einsum==3.3.0 (from paddlepaddle-gpu)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (4.25.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->paddlepaddle-gpu) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle-gpu) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle-gpu) (1.2.2)
# Downloading paddlepaddle_gpu-2.6.2-cp310-cp310-manylinux1_x86_64.whl (758.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 811.6 kB/s eta 0:00:00
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.3 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: opt-einsum, astor, paddlepaddle-gpu
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
# Successfully installed astor-0.8.1 opt-einsum-3.3.0 paddlepaddle-gpu-2.6.2

# %%
# !pip install "paddleocr>=2.0.1"
# Out:
# Collecting paddleocr>=2.0.1
#   Downloading paddleocr-2.9.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (2.0.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (0.25.0)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (0.4.0)
# Collecting pyclipper (from paddleocr>=2.0.1)
#   Downloading pyclipper-1.3.0.post6-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (9.0 kB)
# Collecting lmdb (from paddleocr>=2.0.1)
#   Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.67.1)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (1.26.4)
# Collecting rapidfuzz (from paddleocr>=2.0.1)
#   Downloading rapidfuzz-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.10.0.84)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (3.0.11)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (11.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (6.0.2)
# Collecting python-docx (from paddleocr>=2.0.1)
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.55.3)
# Collecting fire>=0.3.0 (from paddleocr>=2.0.1)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (2.32.3)
# Collecting albumentations==1.4.10 (from paddleocr>=2.0.1)
#   Downloading albumentations-1.4.10-py3-none-any.whl.metadata (38 kB)
# Collecting albucore==0.0.13 (from paddleocr>=2.0.1)
#   Downloading albucore-0.0.13-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.13->paddleocr>=2.0.1) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.13->paddleocr>=2.0.1) (4.12.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.13->paddleocr>=2.0.1) (4.10.0.84)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->paddleocr>=2.0.1) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->paddleocr>=2.0.1) (1.6.0)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->paddleocr>=2.0.1) (2.10.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr>=2.0.1) (2.5.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (2024.12.12)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (0.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->paddleocr>=2.0.1) (2.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr>=2.0.1) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr>=2.0.1) (3.8.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr>=2.0.1) (5.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr>=2.0.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr>=2.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr>=2.0.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr>=2.0.1) (2024.12.14)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr>=2.0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr>=2.0.1) (2.27.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr>=2.0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr>=2.0.1) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (2.8.2)
# Downloading paddleocr-2.9.1-py3-none-any.whl (544 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.7/544.7 kB 19.6 MB/s eta 0:00:00
# Downloading albucore-0.0.13-py3-none-any.whl (8.5 kB)
# Downloading albumentations-1.4.10-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 15.3 MB/s eta 0:00:00
# Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 24.6 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (912 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.2/912.2 kB 47.1 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 19.9 MB/s eta 0:00:00
# Downloading rapidfuzz-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 66.3 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=eb0e35102f3fdd7f4ac3d8affe83343c9a81bc41e1ed6cbda06725d7987aa94e
#   Stored in directory: /root/.cache/pip/wheels/19/39/2f/2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
# Successfully built fire
# Installing collected packages: pyclipper, lmdb, rapidfuzz, python-docx, fire, albucore, albumentations, paddleocr
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.19
#     Uninstalling albucore-0.0.19:
#       Successfully uninstalled albucore-0.0.19
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.20
#     Uninstalling albumentations-1.4.20:
#       Successfully uninstalled albumentations-1.4.20
# Successfully installed albucore-0.0.13 albumentations-1.4.10 fire-0.7.0 lmdb-1.5.1 paddleocr-2.9.1 pyclipper-1.3.0.post6 python-docx-1.1.2 rapidfuzz-3.11.0

# %%
from paddleocr import PaddleOCR,draw_ocr
# Paddleocr supports Chinese, English, French, German, Korean and Japanese.
# You can set the parameter `lang` as `ch`, `en`, `fr`, `german`, `korean`, `japan`
# to switch the language model in order.
ocr = PaddleOCR(use_angle_cls=True, lang='en')

from google.colab.patches import cv2_imshow
import cv2
import json
import numpy as np
# Out:
# /usr/local/lib/python3.10/dist-packages/paddle/base/framework.py:688: UserWarning: You are using GPU version Paddle, but your CUDA device is not set properly. CPU device will be used by default.
#   warnings.warn(
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 3910/3910 [00:17<00:00, 225.15it/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10000/10000 [00:19<00:00, 525.28it/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2138/2138 [00:15<00:00, 136.60it/s]
# [2025/01/02 15:54:00] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')

# %%
# !wget "https://github.com/shreyankg/xkcd-desktop/blob/master/Humor-Sans.ttf?raw=true" -O Humor-Sans.ttf
# !mkdir -p /content/fonts/
# !mv Humor-Sans.ttf /content/fonts/
# Out:
# --2025-01-02 15:54:02--  https://github.com/shreyankg/xkcd-desktop/blob/master/Humor-Sans.ttf?raw=true
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/shreyankg/xkcd-desktop/raw/refs/heads/master/Humor-Sans.ttf [following]
# --2025-01-02 15:54:02--  https://github.com/shreyankg/xkcd-desktop/raw/refs/heads/master/Humor-Sans.ttf
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/shreyankg/xkcd-desktop/refs/heads/master/Humor-Sans.ttf [following]
# --2025-01-02 15:54:02--  https://raw.githubusercontent.com/shreyankg/xkcd-desktop/refs/heads/master/Humor-Sans.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25832 (25K) [application/octet-stream]
# Saving to: ‘Humor-Sans.ttf’
#
# Humor-Sans.ttf      100%[===================>]  25.23K  --.-KB/s    in 0.001s
#
# 2025-01-02 15:54:02 (17.2 MB/s) - ‘Humor-Sans.ttf’ saved [25832/25832]

# %%
import cv2
from paddleocr import PaddleOCR, draw_ocr
import matplotlib.pyplot as plt

def process_image_with_paddleocr(image_path):
    """
    Process an image using PaddleOCR, display the text with bounding boxes,
    and sort the extracted text row and column-wise.

    :param image_path: Path to the input image.
    :return: List of sorted extracted text with bounding boxes.
    """
    ocr = PaddleOCR(use_angle_cls=True, lang='en')


    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


    #  Run OCR
    results = ocr.ocr(gray)


    #  Draw bounding boxes and text on the image
    boxes = [line[0] for line in results[0]]
    texts = [line[1][0] for line in results[0]]
    scores = [line[1][1] for line in results[0]]

    # Draw the boxes on the image
    image_for_drawing = cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)
    annotated_image = draw_ocr(image_for_drawing, boxes, texts, scores, font_path='Humor-Sans.ttf')

    # Visualize the annotated image
    plt.figure(figsize=(10, 10))
    plt.imshow(annotated_image)
    plt.axis('off')
    plt.title("Text and Bounding Boxes")
    plt.show()

    # Step 4: Sort text row-wise and column-wise
    sorted_results = sorted(
        results[0], key=lambda x: (x[0][0][1], x[0][0][0])
    )  # Sort by Y-coordinate, then X-coordinate

    # Format the output for better readability
    formatted_results = [
        {"text": line[1][0], "confidence": line[1][1], "box": line[0]} for line in sorted_results
    ]

    # Print sorted results
    print("Sorted Text:")
    for item in formatted_results:
        print(f"Text: {item['text']}, Confidence: {item['confidence']:.2f}, Box: {item['box']}")

    return formatted_results

# Example usage
image_path = "/content/WhatsApp Image 2024-12-29 at 13.13.07.jpeg"
sorted_text_data = process_image_with_paddleocr(image_path)
# Out:
# [2025/01/02 15:55:53] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/01/02 15:55:55] ppocr DEBUG: dt_boxes num : 73, elapsed : 0.4905238151550293
# [2025/01/02 15:55:55] ppocr DEBUG: cls num  : 73, elapsed : 0.22419977188110352
# [2025/01/02 15:56:03] ppocr DEBUG: rec_res num  : 73, elapsed : 7.595076560974121

# %%
import cv2
from paddleocr import PaddleOCR, draw_ocr
import matplotlib.pyplot as plt

def annotate_image_with_text(image_path):
    """
    Annotates an image with the extracted text directly on its bounding boxes.

    :param image_path: Path to the input image.
    :return: None (displays the annotated image).
    """
    # Initialize PaddleOCR
    ocr = PaddleOCR(use_angle_cls=True, lang='en')

    # Read the image
    image = cv2.imread(image_path)
    if image is None:
        print("Error: Unable to load image. Check the path.")
        return

    # Convert to RGB for display
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    #  Perform OCR
    results = ocr.ocr(image_path)

    # Step 3: Draw text on bounding boxes
    for line in results[0]:
        # Extract bounding box, text, and confidence
        box = line[0]  # Bounding box
        text = line[1][0]  # Extracted text
        confidence = line[1][1]  # Confidence score

        # Convert coordinates to integers
        box = [[int(point[0]), int(point[1])] for point in box]

        # Draw bounding box
        cv2.polylines(image, [np.array(box)], isClosed=True, color=(0, 255, 0), thickness=2)

        # Put text above the bounding box
        text_position = (box[0][0], box[0][1] - 10)  # Slightly above the top-left corner of the box
        cv2.putText(image, text, text_position, cv2.FONT_HERSHEY_SIMPLEX,
                    fontScale=0.6, color=(255, 0, 0), thickness=1, lineType=cv2.LINE_AA)

    #  Display the annotated image
    plt.figure(figsize=(10, 10))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title("Annotated Image with Text")
    plt.show()

# Example usage
image_path = "/content/WhatsApp Image 2024-12-29 at 13.13.07.jpeg"
annotate_image_with_text(image_path)
# Out:
# Sorted Text:
# Text: Date, Confidence: 1.00, Box: [[41.0, 147.0], [80.0, 147.0], [80.0, 167.0], [41.0, 167.0]]
# Text: HHNO234578, Confidence: 0.87, Box: [[470.0, 147.0], [747.0, 149.0], [746.0, 177.0], [470.0, 175.0]]
# Text: R013, Confidence: 0.87, Box: [[369.0, 148.0], [468.0, 148.0], [468.0, 176.0], [369.0, 176.0]]
# Text: TITLE (Mt/MsDr.oc, Confidence: 0.80, Box: [[185.0, 180.0], [285.0, 183.0], [284.0, 202.0], [184.0, 198.0]]
# Text: FIRST NAME, Confidence: 0.96, Box: [[568.0, 187.0], [625.0, 187.0], [625.0, 201.0], [568.0, 201.0]]
# Text: MIDDLE NAME, Confidence: 0.95, Box: [[771.0, 191.0], [837.0, 191.0], [837.0, 204.0], [771.0, 204.0]]
# Text: Name, Confidence: 1.00, Box: [[41.0, 199.0], [89.0, 199.0], [89.0, 219.0], [41.0, 219.0]]
# Text: ABCDEFGHISKLMNOPORSTUVWXYZ, Confidence: 0.87, Box: [[297.0, 199.0], [870.0, 204.0], [870.0, 231.0], [297.0, 225.0]]
# Text: MR, Confidence: 0.98, Box: [[186.0, 200.0], [240.0, 200.0], [240.0, 225.0], [186.0, 225.0]]
# Text: 2003, Confidence: 0.94, Box: [[345.0, 260.0], [439.0, 263.0], [438.0, 292.0], [344.0, 289.0]]
# Text: 06, Confidence: 0.91, Box: [[260.0, 263.0], [310.0, 263.0], [310.0, 288.0], [260.0, 288.0]]
# Text: Age2Years 2Months Days, Confidence: 0.92, Box: [[567.0, 263.0], [901.0, 268.0], [901.0, 295.0], [566.0, 289.0]]
# Text: Date of Birth, Confidence: 0.96, Box: [[45.0, 264.0], [141.0, 264.0], [141.0, 283.0], [45.0, 283.0]]
# Text: Marital Status, Confidence: 0.98, Box: [[45.0, 298.0], [151.0, 301.0], [150.0, 322.0], [45.0, 319.0]]
# Text: single, Confidence: 0.95, Box: [[318.0, 298.0], [408.0, 302.0], [407.0, 326.0], [317.0, 322.0]]
# Text: Married, Confidence: 0.99, Box: [[214.0, 301.0], [279.0, 301.0], [279.0, 321.0], [214.0, 321.0]]
# Text: Widowed, Confidence: 0.99, Box: [[482.0, 303.0], [558.0, 303.0], [558.0, 325.0], [482.0, 325.0]]
# Text: Divorced, Confidence: 1.00, Box: [[613.0, 304.0], [688.0, 304.0], [688.0, 327.0], [613.0, 327.0]]
# Text: Male, Confidence: 0.96, Box: [[187.0, 332.0], [264.0, 332.0], [264.0, 360.0], [187.0, 360.0]]
# Text: Gender, Confidence: 1.00, Box: [[47.0, 333.0], [106.0, 336.0], [105.0, 356.0], [46.0, 353.0]]
# Text: Others, Confidence: 1.00, Box: [[481.0, 336.0], [538.0, 336.0], [538.0, 360.0], [481.0, 360.0]]
# Text: Female, Confidence: 1.00, Box: [[358.0, 337.0], [416.0, 337.0], [416.0, 357.0], [358.0, 357.0]]
# Text: Occupation, Confidence: 1.00, Box: [[48.0, 366.0], [137.0, 370.0], [136.0, 390.0], [47.0, 386.0]]
# Text: ABCDEEGHISK, Confidence: 0.88, Box: [[189.0, 368.0], [439.0, 372.0], [439.0, 399.0], [188.0, 395.0]]
# Text: Religion:MWOPQRSTU, Confidence: 0.79, Box: [[525.0, 371.0], [821.0, 375.0], [821.0, 397.0], [524.0, 393.0]]
# Text: RATASTHAN, Confidence: 0.97, Box: [[191.0, 402.0], [381.0, 407.0], [380.0, 430.0], [191.0, 425.0]]
# Text: Resi.Address, Confidence: 0.99, Box: [[49.0, 408.0], [153.0, 408.0], [153.0, 427.0], [49.0, 427.0]]
# Text: City/Town, Confidence: 0.99, Box: [[51.0, 467.0], [134.0, 467.0], [134.0, 485.0], [51.0, 485.0]]
# Text: BIKANER, Confidence: 0.91, Box: [[192.0, 467.0], [340.0, 467.0], [340.0, 489.0], [192.0, 489.0]]
# Text: Pin/Zip Code:23456, Confidence: 0.94, Box: [[547.0, 472.0], [793.0, 472.0], [793.0, 491.0], [547.0, 491.0]]
# Text: AGCDEFGHIJKL, Confidence: 0.88, Box: [[191.0, 501.0], [447.0, 505.0], [447.0, 528.0], [191.0, 524.0]]
# Text: State, Confidence: 1.00, Box: [[50.0, 505.0], [94.0, 505.0], [94.0, 525.0], [50.0, 525.0]]
# Text: CountryINDA, Confidence: 0.96, Box: [[589.0, 509.0], [775.0, 509.0], [775.0, 528.0], [589.0, 528.0]]
# Text: Nationality, Confidence: 0.99, Box: [[49.0, 534.0], [134.0, 538.0], [134.0, 560.0], [48.0, 557.0]]
# Text: twolen, Confidence: 0.54, Box: [[192.0, 537.0], [313.0, 537.0], [313.0, 556.0], [192.0, 556.0]]
# Text: Tel.No.Res.), Confidence: 0.94, Box: [[52.0, 565.0], [153.0, 568.0], [153.0, 591.0], [51.0, 588.0]]
# Text: 345689, Confidence: 0.77, Box: [[192.0, 566.0], [403.0, 572.0], [402.0, 596.0], [191.0, 590.0]]
# Text: 3333333333, Confidence: 0.99, Box: [[617.0, 571.0], [857.0, 573.0], [856.0, 596.0], [616.0, 593.0]]
# Text: Office:, Confidence: 0.98, Box: [[546.0, 575.0], [610.0, 575.0], [610.0, 593.0], [546.0, 593.0]]
# Text: (STD/SD Code, Confidence: 0.84, Box: [[202.0, 596.0], [271.0, 596.0], [271.0, 609.0], [202.0, 609.0]]
# Text: STD/SO Code, Confidence: 0.83, Box: [[618.0, 601.0], [682.0, 601.0], [682.0, 615.0], [618.0, 615.0]]
# Text: Mobile 1, Confidence: 0.93, Box: [[51.0, 613.0], [118.0, 613.0], [118.0, 632.0], [51.0, 632.0]]
# Text: 234321, Confidence: 0.87, Box: [[194.0, 615.0], [424.0, 615.0], [424.0, 637.0], [194.0, 637.0]]
# Text: 9876543210, Confidence: 0.89, Box: [[617.0, 620.0], [833.0, 621.0], [833.0, 644.0], [617.0, 643.0]]
# Text: Mobile2, Confidence: 0.99, Box: [[526.0, 621.0], [613.0, 621.0], [613.0, 640.0], [526.0, 640.0]]
# Text: abcdeaH@GnAcOn, Confidence: 0.66, Box: [[193.0, 648.0], [575.0, 655.0], [574.0, 677.0], [192.0, 671.0]]
# Text: Email-ld, Confidence: 0.94, Box: [[54.0, 652.0], [118.0, 652.0], [118.0, 671.0], [54.0, 671.0]]
# Text: Resoonsible Person/Kin Details, Confidence: 0.93, Box: [[58.0, 684.0], [306.0, 684.0], [306.0, 707.0], [58.0, 707.0]]
# Text: Relation, Confidence: 0.99, Box: [[54.0, 713.0], [120.0, 716.0], [119.0, 736.0], [53.0, 733.0]]
# Text: Father, Confidence: 0.97, Box: [[180.0, 715.0], [286.0, 715.0], [286.0, 737.0], [180.0, 737.0]]
# Text: Mother HusbandwifeOther, Confidence: 0.95, Box: [[324.0, 715.0], [656.0, 717.0], [656.0, 741.0], [324.0, 739.0]]
# Text: TITLE Mr./Ms.D.to, Confidence: 0.71, Box: [[192.0, 747.0], [286.0, 747.0], [286.0, 761.0], [192.0, 761.0]]
# Text: LAST (SURNAME, Confidence: 0.90, Box: [[351.0, 749.0], [424.0, 749.0], [424.0, 763.0], [351.0, 763.0]]
# Text: FIRST NAME, Confidence: 0.92, Box: [[561.0, 751.0], [614.0, 751.0], [614.0, 765.0], [561.0, 765.0]]
# Text: Name, Confidence: 1.00, Box: [[55.0, 760.0], [102.0, 763.0], [101.0, 783.0], [54.0, 780.0]]
# Text: DR, Confidence: 0.97, Box: [[195.0, 765.0], [255.0, 765.0], [255.0, 785.0], [195.0, 785.0]]
# Text: AB, Confidence: 0.55, Box: [[325.0, 769.0], [385.0, 769.0], [385.0, 788.0], [325.0, 788.0]]
# Text: Contact No., Confidence: 0.95, Box: [[58.0, 821.0], [145.0, 821.0], [145.0, 840.0], [58.0, 840.0]]
# Text: 33456890, Confidence: 0.83, Box: [[196.0, 821.0], [402.0, 821.0], [402.0, 844.0], [196.0, 844.0]]
# Text: Emergency, Confidence: 0.99, Box: [[57.0, 849.0], [143.0, 852.0], [142.0, 871.0], [57.0, 868.0]]
# Text: 034569, Confidence: 0.75, Box: [[197.0, 859.0], [424.0, 861.0], [424.0, 884.0], [196.0, 881.0]]
# Text: Contact No, Confidence: 0.96, Box: [[60.0, 868.0], [142.0, 871.0], [142.0, 886.0], [59.0, 883.0]]
# Text: Doctor's Details, Confidence: 0.95, Box: [[60.0, 889.0], [179.0, 892.0], [178.0, 916.0], [59.0, 913.0]]
# Text: AGCDEFGHISKLMN, Confidence: 0.86, Box: [[195.0, 923.0], [489.0, 927.0], [489.0, 949.0], [195.0, 945.0]]
# Text: Doctor's Name, Confidence: 0.98, Box: [[61.0, 924.0], [169.0, 924.0], [169.0, 943.0], [61.0, 943.0]]
# Text: Referring Doctors ab cd efgijR, Confidence: 0.87, Box: [[59.0, 952.0], [427.0, 964.0], [426.0, 987.0], [58.0, 974.0]]
# Text: Name, Confidence: 1.00, Box: [[60.0, 972.0], [106.0, 975.0], [105.0, 991.0], [59.0, 988.0]]
# Text: Roferring Doctor'sg8765432, Confidence: 0.86, Box: [[58.0, 992.0], [426.0, 1006.0], [425.0, 1036.0], [57.0, 1022.0]]
# Text: Contact Number, Confidence: 0.97, Box: [[62.0, 1017.0], [183.0, 1017.0], [183.0, 1035.0], [62.0, 1035.0]]
# [2025/01/02 15:56:04] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/01/02 15:56:05] ppocr DEBUG: dt_boxes num : 74, elapsed : 0.26738739013671875
# [2025/01/02 15:56:06] ppocr DEBUG: cls num  : 74, elapsed : 0.23078203201293945
# [2025/01/02 15:56:10] ppocr DEBUG: rec_res num  : 74, elapsed : 4.366581678390503

# %%
import cv2
from paddleocr import PaddleOCR

def sort_text_row_col(image_path):
    """
    Extracts text from an image and sorts it row-wise and column-wise.

    :param image_path: Path to the input image.
    :return: List of rows, each containing column-sorted text.
    """
    # Initialize PaddleOCR
    ocr = PaddleOCR(use_angle_cls=True, lang='en')

    # Perform OCR on the image
    results = ocr.ocr(image_path)

    # Extract bounding boxes and text
    extracted_data = []
    for line in results[0]:
        box = line[0]  # Bounding box
        text = line[1][0]  # Extracted text
        y_center = (box[0][1] + box[2][1]) / 2  # Calculate y-center for row grouping
        x_center = (box[0][0] + box[2][0]) / 2  # Calculate x-center for column sorting
        extracted_data.append((y_center, x_center, text))

    # Sort data by y-center (row-wise), then by x-center (column-wise)
    extracted_data.sort(key=lambda item: (item[0], item[1]))

    # Group data into rows
    row_tolerance = 15  # Tolerance for considering text in the same row
    rows = []
    current_row = []

    for i, data in enumerate(extracted_data):
        if i == 0 or abs(data[0] - extracted_data[i - 1][0]) < row_tolerance:
            current_row.append(data)
        else:
            rows.append(current_row)
            current_row = [data]
    if current_row:
        rows.append(current_row)

    # Sort text within each row by x-center and prepare final sorted output
    sorted_rows = []
    for row in rows:
        row.sort(key=lambda item: item[1])
        sorted_rows.append([item[2] for item in row])

    return sorted_rows

# Example usage
image_path = "/content/WhatsApp Image 2024-12-29 at 13.13.07.jpeg"
sorted_text = sort_text_row_col(image_path)

# Display sorted rows and columns
for i, row in enumerate(sorted_text):
    print(f"Row {i + 1}: {row}")
# Out:
# [2025/01/02 15:56:11] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/01/02 15:56:12] ppocr DEBUG: dt_boxes num : 74, elapsed : 0.26218652725219727
# [2025/01/02 15:56:13] ppocr DEBUG: cls num  : 74, elapsed : 0.21698451042175293
# [2025/01/02 15:56:18] ppocr DEBUG: rec_res num  : 74, elapsed : 5.476665735244751
# Row 1: ['Date', 'R013', 'HHNO234578']
# Row 2: ['Name', 'MR', 'TITLE (Mt/MsDr.oc', 'ASTISURNAME', 'ABCDEFGHISKLMNOPORSTUVWXYZ', 'FIRST NAME', 'MIDDLE NAME']
# Row 3: ['Date of Birth', '5T', '06', '2003', 'Age2Years 2Months Days']
# Row 4: ['Marital Status', 'Married', 'single', 'Widowed', 'Divorced']
# Row 5: ['Gender', 'Male', 'Female', 'Others']
# Row 6: ['Occupation', 'ABCDEFGHISK', 'Religion:MWOPQRSTU']
# Row 7: ['Resi.Address', 'RATASTHAN']
# Row 8: ['City/Town', 'BIKANER', 'Pin/Zip Code:23456']
# Row 9: ['State', 'AGCDEFGHIJKL', 'CountryINDA']
# Row 10: ['Nationality']
# Row 11: ['Tel.No.Res.)', '3345689', 'Office:', '3333333333']
# Row 12: ['Mobile 1', '(STD/SD Code)', '234321', 'Mobile2', 'STD/SO Code', '9876543210']
# Row 13: ['Email-ld', 'abcdefaHoGnArcon']
# Row 14: ['Resoonsible Person/Kin Details']
# Row 15: ['Relation', 'Father', 'Mother Husbandwife Other']
# Row 16: ['Name', 'DR', 'TTLE Mr/Ms/Dreto', 'LAST (SURNAME', 'FIRST NAME']
# Row 17: ['Contact No.', '334567890']
# Row 18: ['Emergency', 'Contact No', '035569']
# Row 19: ["Doctor's Details"]
# Row 20: ["Doctor's Name", 'AGCDEFGHISKLMN']
# Row 21: ['Name', "Referring Doctor's abcdefgnijR"]
# Row 22: ['Contact Number', "Roferring Doctor'sg8765432"]
